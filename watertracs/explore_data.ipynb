# %% [markdown]
# # Brief notebook to explore given WaterTRACS EA waterpoint testing data
#
# @auth dpb
#
# Data from Anna / Karen / WaterTRACS c. Oct 2024

# %%
import os
import pandas as pd
import geopandas as gpd

# %%
data_dir = "/Users/datascience/Aquaya Dropbox/Duncan Penfold-Brown/Project W II/Data/WaterTRACS Data Vis/"
data_file = os.path.join(data_dir, "Hilton_WP_data_Combined_2024-10-02.csv")

# %%
keep_cols = ["country_wp", "district_wp", "Clean_Date_wp", "ea_wp", "ea_code_wp", "wp_site_id_code1",
        "wptype", "institutional_wp", "wateravailable", "collectsample", 'survey_round_wp', 'wet_season_wp',
        'ph', 'conductivity', 'temperature', 'turbidity', 'ecoli_wp', 'ecoli_wp_cat', 'latitude_wp', 'longitude_wp']

col_rename = {"Clean_Date_wp": "sample_date", "wp_site_id_code1": "wp_site_id", "wptype": "wp_type"}

# %% [markdown]
# ### Load and basic clean

# %%
df = pd.read_csv(data_file, encoding="ISO-8859-1", usecols=keep_cols)
df = df.sort_values(["country_wp", "district_wp", "ea_wp", "wp_site_id_code1", "survey_round_wp"])
df = df[keep_cols].copy()
df = df.rename(columns=col_rename)

# Drop all rows (samples) where the E Coli results are Null (ie, a test wasn't done) - we'll just do this for now
df = df.dropna(how="any", subset=["ecoli_wp", "ecoli_wp_cat"])
df.shape
# Out:
# (3980, 20)

# %%
df.head(2)
# Out:
#      country_wp district_wp sample_date ea_wp         ea_code_wp  wp_site_id  \
# 1923   Ethiopia        Dera   7/28/2022  Agar  ea_03020988802001   430484593
# 3201   Ethiopia        Dera   1/24/2023  Agar  ea_03020988802001   430484593
#
#       wp_type  institutional_wp  wateravailable  collectsample  \
# 1923       12                 0               1              1
# 3201       10                 0               1              1
#
#       survey_round_wp wet_season_wp    ph  conductivity  temperature  \
# 1923                0           wet  6.79         102.0         18.1
# 3201                1           dry  7.20         142.0         13.1
#
#       turbidity  ecoli_wp  ecoli_wp_cat  latitude_wp  longitude_wp
# 1923     102.00     101.0           3.0    11.641217     37.673716
# 3201       2.07     101.0           3.0    11.641270     37.673826

# %% [markdown]
# ### Transform to GeoDataFrame (load geom from lat/lon)

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.GeoSeries.from_xy(df["longitude_wp"], df["latitude_wp"]), crs=4326)
gdf.shape
# Out:
# (3980, 21)

# %% [markdown]
# ### Filter to select EA

# %%
select_ea_code = "204"

# %%
ea_gdf = gdf[gdf["ea_code_wp"]==select_ea_code].copy()
ea_gdf.shape
# Out:
# (27, 21)

# %% [markdown]
# ## Explore on Map
#
# - Available tiles: `"OpenStreetMap", "CartoDB positron", “CartoDB dark_matter"`
# - Marker types (for now): ‘marker’, ‘circle’, ‘circle_marker’
#
#
# **Documentation for further map customization** (see icons, colors, marker styling, etc): https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.explore.html

# %%
tooltip_cols = ["country_wp", "district_wp", "sample_date", "ea_wp", "ea_code_wp", "wp_site_id",
        "wp_type", "institutional_wp", "wateravailable", "collectsample", 'survey_round_wp', 'wet_season_wp',
        'ph', 'conductivity', 'temperature', 'turbidity', 'ecoli_wp', 'ecoli_wp_cat']

popup_cols = ["country_wp", "district_wp", "sample_date", "ea_wp", "wp_site_id",
        "wp_type", 'wet_season_wp', 'ecoli_wp', 'ecoli_wp_cat']

# %%
fig = ea_gdf.explore(column="ecoli_wp", cmap="coolwarm", tiles="OpenStreetMap",
                     tooltip=tooltip_cols, popup=popup_cols,
                     marker_type="circle_marker", marker_kwds={"radius": 10, "fill": True})
fig
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89d07670c5748605ce09c3b391b8eb22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89d07670c5748605ce09c3b391b8eb22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89d07670c5748605ce09c3b391b8eb22 = L.map(
#                 &quot;map_89d07670c5748605ce09c3b391b8eb22&quot;,
#                 {
#                     center: [0.7055343, 30.1856183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_89d07670c5748605ce09c3b391b8eb22);
#
#
#
#
#
#             var tile_layer_a223babb5ccc3efa7e7cab15a4be502f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a223babb5ccc3efa7e7cab15a4be502f.addTo(map_89d07670c5748605ce09c3b391b8eb22);
#
#
#             map_89d07670c5748605ce09c3b391b8eb22.fitBounds(
#                 [[0.7007583, 30.1817967], [0.7103103, 30.1894399]],
#                 {}
#             );
#
#
#         function geo_json_1326344e720fa7e59743ec960663ed61_styler(feature) {
#             switch(feature.id) {
#                 case &quot;2576&quot;:
#                     return {&quot;color&quot;: &quot;#7396f5&quot;, &quot;fillColor&quot;: &quot;#7396f5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4499&quot;:
#                     return {&quot;color&quot;: &quot;#e0dbd8&quot;, &quot;fillColor&quot;: &quot;#e0dbd8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1203&quot;:
#                     return {&quot;color&quot;: &quot;#8caffe&quot;, &quot;fillColor&quot;: &quot;#8caffe&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2585&quot;:
#                     return {&quot;color&quot;: &quot;#7a9df8&quot;, &quot;fillColor&quot;: &quot;#7a9df8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4509&quot;:
#                     return {&quot;color&quot;: &quot;#f4c5ad&quot;, &quot;fillColor&quot;: &quot;#f4c5ad&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2588&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#a1c0ff&quot;, &quot;fillColor&quot;: &quot;#a1c0ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1202&quot;:
#                     return {&quot;color&quot;: &quot;#f6a385&quot;, &quot;fillColor&quot;: &quot;#f6a385&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2577&quot;: case &quot;3&quot;: case &quot;1201&quot;:
#                     return {&quot;color&quot;: &quot;#3d50c3&quot;, &quot;fillColor&quot;: &quot;#3d50c3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1208&quot;: case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#3b4cc0&quot;, &quot;fillColor&quot;: &quot;#3b4cc0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2584&quot;:
#                     return {&quot;color&quot;: &quot;#5b7ae5&quot;, &quot;fillColor&quot;: &quot;#5b7ae5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2578&quot;:
#                     return {&quot;color&quot;: &quot;#88abfd&quot;, &quot;fillColor&quot;: &quot;#88abfd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2582&quot;:
#                     return {&quot;color&quot;: &quot;#779af7&quot;, &quot;fillColor&quot;: &quot;#779af7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4507&quot;

# %%
fig.save(outfile="sample_map.html")
